# %%
# JOUR 1 – ANTONIN COLOMBANI – OBJECTIF SALAIRE
print("Antonin Colombani – Tours")
print("Jour 1 : je commence à coder pour gagner mon pain")
print("Pas de blabla, pas de rêve → que des lignes qui tournent")

# Tes premières variables (change les valeurs avec TA vraie vie)
age = 25
revenu_actuel = 900        # € net/mois actuel (mets le vrai chiffre)
revenu_vise_mois6 = 1400   # alternance réaliste
revenu_vise_mois12 = 35000 # CDI junior réaliste

print(f"Actuel : {revenu_actuel} €/mois")
print(f"Mois 6 : +{revenu_vise_mois6 - revenu_actuel} € net")
print(f"Mois 12 : {revenu_vise_mois12} € brut/an")
# Out:
# Antonin Colombani – Tours
# Jour 1 : je commence à coder pour gagner mon pain
# Pas de blabla, pas de rêve → que des lignes qui tournent
# Actuel : 900 €/mois
# Mois 6 : +500 € net
# Mois 12 : 35000 € brut/an

# %%
nom = "Antonin Colombani"
ville = "Tours en Indre et Loire"
age_reel = 25 # les 26 ans ca pete tout 

print(f"Je m'appelle {nom}")
print(f"j'habite à {ville} et j'ai {age_reel}")
# Out:
# Je m'appelle Antonin Colombani
# j'habite à Tours en Indre et Loire et j'ai 25

# %%
# Mes objectifs concrets 
revenu_actuel = 900     # € net/mois &ujourd'hui
revenu_alternance = 1400
revenu_cdi = 35000

# Calculsalaire mensuel brut en CDI (division) 
salaire_mensuel_brut = revenu_cdi / 12

# Affiche proprement
print(f"Revenu actuel : {revenu_actuel} € net/mois")
print(f"Revenu alternance : {revenu_alternance} € net/mois")
print(f"Revenu CDI annuel : {revenu_cdi} € brut/an")
print(f"Salaire mensuel brut CDI : {salaire_mensuel_brut} €")
# Out:
# Revenu actuel : 900 € net/mois
# Revenu alternance : 1400 € net/mois
# Revenu CDI annuel : 35000 € brut/an
# Salaire mensuel brut CDI : 2916.6666666666665 €

# %%
# Objectif : arrondir le salaire mensuel brut a l'euro près 

salaire_mensuel_brut = revenu_cdi / 12
salaire_arrondi = round(salaire_mensuel_brut)

print(f"Salaire mensuel brut CDI (arrondi) : {salaire_arrondi} €")
# Out:
# Salaire mensuel brut CDI (arrondi) : 2917 €

# %%
revenu_actuel = 900
augmentation_pourcent = 55 # % d'augmentation entre aujourd'hui et l'alternance 

revenu_apres_augmentation = revenu_actuel * (1 + augmentation_pourcent / 100)
revenu_apres_augmentation_arrondi = round(revenu_apres_augmentation)

print(f"Dans 6 mois : {revenu_apres_augmentation} € net/mois")
print(f"Soit + {revenu_apres_augmentation_arrondi - revenu_actuel} € par rapport à aujourd'hui")
# Out:
# Dans 6 mois : 1395.0 € net/mois
# Soit + 495 € par rapport à aujourd'hui

# %%
salaire_brut_annuel = 35000
impots_charges = salaire_brut_annuel * 0.23
salaire_net_annuel = salaire_brut_annuel - impots_charges
salaire_net_mensuel = round(salaire_net_annuel / 12)

print(f"Salaire net annuel estime : {round(salaire_net_annuel)} €")
print(f"Salaire net mensuel estime : {salaire_net_mensuel} €")
# Out:
# Salaire net annuel estime : 26950 €
# Salaire net mensuel estime : 2246 €

# %%
prix_vacances = 4000
salaire_net_mensuel = 2500 # estimation réaliste net en CDI junior

mois_pour_payer = prix_vacances / salaire_net_mensuel
mois_arrondi = round(mois_pour_payer * 10) / 10 # 1 decimale 

print(f"Avec {salaire_net_mensuel} € net/mois")
print(f"je paye les 4000€ de vacances en {mois_arrondi} mois suelement.")
# Out:
# Avec 2500 € net/mois
# je paye les 4000€ de vacances en 1.6 mois suelement.
